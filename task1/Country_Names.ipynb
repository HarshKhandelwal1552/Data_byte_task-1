# %%
import pandas as pd

# %%
df = pd.read_csv('data_csv.csv')

# %%
# display the starting 7 entries
df.head(7)
# Out:
#           Name Code
# 0      Ecuador   EC
# 1   Bangladesh   BD
# 2   Madagascar   MG
# 3  Saint Lucia   LC
# 4        Spain   ES
# 5     Mongolia   MN
# 6     Bulgaria   BG

# %%
df_name = df['Name']
df_code = df['Code']

# %%
  class country():

    def __init__(self):
      self.handler = {}
      self.flag= False

# the below function collects all the country codes required
    def filter(self):
      for (key, val) in df.items():
          if key == self.c_code1:
              self.flag= True
              continue
          elif key == self.c_code2:
              self.flag= False
              break
          if self.flag:
              self.handler[key] = val
# the below function uses the above filter to get the country names and sort them in alphabetic order
    def display_sorted(self, cc1, cc2):
      self.c_code1 = c_code1
      self.c_code2 = c_code2

      self.filter()

      # if code 2 is above than code 1 reverse the order and get the country names
      if not bool(self.handler):
        print("yes")
        self.c_code1 = self.c_code2
        self.c_code2 = self.c_code1

        self.filter()
        
      # sorting the country names
      self.handler = {k: v for k, v in sorted(self.handler.items(), key=lambda item: item[1])}

      for key, val in self.handler.items():
        print(val)

# %%
df = dict(zip(list(df_code), list(df_name)))

c_code1 = input("Country Code1 : ")
# c_code1= "US"
c_code2 = input("Country code2 : ")
# c_code2 = "IN"

# making a class instance and displaying the country names
country().display_sorted(c_code1, c_code2)
# Out:
# Afghanistan
# Albania
# American Samoa
# Andorra
# Angola
# Anguilla
# Antarctica
# Antigua and Barbuda
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahrain
# Barbados
# Belarus
# Bermuda
# Bhutan
# Bonaire, Sint Eustatius and Saba
# Bosnia and Herzegovina
# Bouvet Island
# Brazil
# Brunei Darussalam
# Burkina Faso
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Central African Republic
# Chad
# Chile
# China
# Christmas Island
# Cocos (Keeling) Islands
# Colombia
# Comoros
# Congo
# Congo, the Democratic Republic of the
# Cook Islands
# Croatia
# Curaçao
# Czech Republic
# Côte d'Ivoire
# Dominica
# Dominican Republic
# Egypt
# Equatorial Guinea
# Eritrea
# Ethiopia
# Falkland Islands (Malvinas)
# Faroe Islands
# Fiji
# Finland
# France
# French Guiana
# Gabon
# Gambia
# Georgia
# Ghana
# Gibraltar
# Greece
# Grenada
# Guadeloupe
# Guam
# Guatemala
# Guernsey
# Guinea-Bissau
# Heard Island and McDonald Islands
# Hong Kong
# Iceland
# Indonesia
# Iraq
# ...
